# %%
# Download All data
import wget
from selenium import webdriver
import os
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import json
from selenium.webdriver.common.alert import Alert
import time
import urllib.request

CHAR_LIST = ['Argenti', 'Arlan', 'Asta', 'Bailu', 'Blade', 'Bronya', 'Clara', 'Dan Heng', 'Dan Heng ? Imbibitor Lunae', 'Dr. Ratio', 'Fu Xuan', 'Gepard', 'Guinaifen', 'Hanya', 'Herta', 'Himeko', 'Hook', 'Huohuo', 'Jing Yuan', 'Jingliu', 'Kafka', 'Luka', 'Luocha', 'Lynx', 'March 7th', 'Natasha', 'Pela', 'Qingque', 'Ruan Mei', 'Sampo', 'Seele', 'Serval', 'Silver Wolf', 'Sushang', 'Tingyun', 'Topaz and Numby', 'Trailblazer', 'Welt', 'Xueyi', 'Yanqing', 'Yukong']

for i in CHAR_LIST:
    # CHANGE SETTINGS AND RUNNING THIS CODE
    # Settings (설정)
    CHARACTOR_TARGET_ID = f'{i}'
    CHARACTOR_LANGUAGE_ID = 'Korean'
    TARGET_BROWSER = 'Chrome'
    TARGET_SAVE = 'C:\\Users\\starl\\Documents\\tts\\kors'
    TARGET_TYPE_ONLY_TRAVELER = 'Stelle'
    # if you want Aether only, just do it
    # Or Lumine, Chage 'Aether' to 'Lumine'
    # Warning : This Notebook Can't Work on Google Colab (구글 코랩에서는 작동이 허용되지 않을 수 있습니다)

    print(f"now downloading Chractor : {CHARACTOR_TARGET_ID}\nLanguage_ID : {CHARACTOR_LANGUAGE_ID}")
    print(f'Downloading With {TARGET_BROWSER}')

    LINK_URL = f'https://honkai-star-rail.fandom.com/wiki/{CHARACTOR_TARGET_ID}/Voice-Overs/{CHARACTOR_LANGUAGE_ID}'

    option = Options()
    option.add_argument("disable-infobars")
    option.add_argument("disable-extensions")
    user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17 "
    option.add_argument('user-agent=' + user_agent)
    option.add_argument('disable-gpu')
    option.add_argument('incognito') 
    option.add_argument('headless')

    s = Service(ChromeDriverManager().install())
    browser = webdriver.Chrome(service=s, options=option)

    browser.get(LINK_URL)
    os.chdir(TARGET_SAVE)
    data_code = []

    if not os.path.exists(TARGET_SAVE + '/' + CHARACTOR_TARGET_ID):
        os.makedirs(TARGET_SAVE + '/' + CHARACTOR_TARGET_ID)

    data = browser.find_elements(By.TAG_NAME, 'table')
    for i in data:
        for j in i.find_elements(By.TAG_NAME, 'td'):
            try:
                text = j.find_element(By.CSS_SELECTOR, 'span:nth-child(3)').text
            except:
                text = 'None'
            audio = j.find_elements(By.CSS_SELECTOR, 'span.audio-button.custom-theme.hidden > a')
            print(audio)
            try:
                os.chdir(TARGET_SAVE + '/' + CHARACTOR_TARGET_ID)
                print("Audio : ", audio[0].get_attribute('href'))
                # print("Audio Downloading...")
                file_name = audio[0].get_attribute('href').split('.ogg')[0].split('/')[-1] + '.ogg'
                print(file_name)
                # wget.download(audio[0].get_attribute('href'))
                if(TARGET_TYPE_ONLY_TRAVELER == 'Stelle'):
                    # print(audio[0].get_attribute('href').replace('Aether', 'Lumine'))
                    wget.download(audio[0].get_attribute('href').replace('Caelus', 'Stelle'))
                else:
                    wget.download(audio[0].get_attribute('href'))
                data_code.append({'file_name' : file_name, 'text' : text})
            except:
                print("Audio : None")
            print("Text : ", text)

    os.chdir(TARGET_SAVE)
    print(data_code)

    # text_generation
    os.chdir(TARGET_SAVE + '/' + CHARACTOR_TARGET_ID)
    with open('data.txt', 'w', encoding='utf-8') as f:
        for item in data_code:
            if(item['text'] == 'None' or item['file_name'] == 'None'):
                continue
            f.write(f'{item["file_name"]}  ||  {item["text"]}\n')
            
    print('Complete Downloading!')
    browser.quit()
# Out:
# now downloading Chractor : Argenti
# Language_ID : Korean
# Downloading With Chrome
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_166")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/c/cf/VO_Archive_Argenti_1.ogg/revision/latest?cb=20240114205526
# VO_Archive_Argenti_1.ogg
# Text :  My name is Argenti, I belong to the Knights of Beauty. May this rose convey my heartfelt salutations.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_168")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/c/c5/VO_Archive_Argenti_2.ogg/revision/latest?cb=20240114205527
# VO_Archive_Argenti_2.ogg
# Text :  Should misfortune befall you, do not hesitate to call upon me. I will protect you.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_170")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/3/35/VO_Archive_Argenti_3.ogg/revision/latest?cb=20240114205528
# VO_Archive_Argenti_3.ogg
# Text :  Forgive me, here we must part ways. It is my duty and destiny to traverse the universe alone. I'm sure our paths will converge again, somewhere.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_172")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/3/3d/VO_Archive_Argenti_4.ogg/revision/latest?cb=20240114205529
# VO_Archive_Argenti_4.ogg
# Text :  Among the Knights of Beauty, I am one of the Honorclad — we are distinguished by our engraved armor.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_174")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/4/4f/VO_Archive_Argenti_5.ogg/revision/latest?cb=20240114205530
# VO_Archive_Argenti_5.ogg
# Text :  The Knights tend to operate in solitude, spreading the grace of the Goddess far and wide across the universe. Nevertheless, we follow the same code of chivalry.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_176")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/c/c9/VO_Archive_Argenti_6.ogg/revision/latest?cb=20240114205531
# VO_Archive_Argenti_6.ogg
# Text :  "One and Only" is the name of my spaceship. I must admit, keeping her in good order can be a chore. Perhaps I shouldn't have etched such intricate patterns into the fuselage.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_178")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/9/93/VO_Archive_Argenti_7.ogg/revision/latest?cb=20240114205533
# VO_Archive_Argenti_7.ogg
# Text :  I have a preference for thick, crusty baguettes. Slice them thinly so they're easier to store — a crucial snack for extended voyages.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_180")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/3/3a/VO_Archive_Argenti_8.ogg/revision/latest?cb=20240114205534
# VO_Archive_Argenti_8.ogg
# Text :  The dazzling array of entertainment and gourmet delights offered by the IPC is quite staggering, but I regularly struggle with making sense of it all. Perhaps one day someone with experience will show me the ropes.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_182")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/2f/VO_Archive_Argenti_9.ogg/revision/latest?cb=20240114205535
# VO_Archive_Argenti_9.ogg
# Text :  I've heard tales of warriors on a certain planet passing book pages over artificial limbs in order to infuse knowledge directly into their neural systems. It sounds so outlandish, and yet I find the idea quite inspired.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_184")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/0/0c/VO_Archive_Argenti_10.ogg/revision/latest?cb=20240114205536
# VO_Archive_Argenti_10.ogg
# Text :  Did you ever hear tell of a planet where there is no concept of grotesquery? Even more intriguing — the people there have no concept of beauty, either.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_186")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/1/15/VO_Archive_Argenti_11.ogg/revision/latest?cb=20240114205538
# VO_Archive_Argenti_11.ogg
# Text :  Miss March possesses a pure heart, and such purity is rare and precious — there are far too many people who are inherently vulgar, profit-driven, and adept at flattery. I wish to extend more compassion and esteem towards people like her.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_188")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/2e/VO_Archive_Argenti_12.ogg/revision/latest?cb=20240114205539
# VO_Archive_Argenti_12.ogg
# Text :  This lady's spirit is admirably noble: Despite the challenges and hardships that Trailblazing entails, she has retained her poise and bravery — qualities that I profoundly admire. It is these qualities that I strive to embody and use against evil.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_192")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/d/d4/VO_Archive_Argenti_13.ogg/revision/latest?cb=20240114205540
# VO_Archive_Argenti_13.ogg
# Text :  While Mr. Dan Heng consistently maintains a sense of wariness towards others, his conduct remains unwaveringly honorable, and his expectations of himself are as stringent as the chivalric code. He possesses a unique form of beauty, I must say.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_194")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/8/88/VO_Archive_Argenti_14.ogg/revision/latest?cb=20240114205541
# VO_Archive_Argenti_14.ogg
# Text :  Despite the things he has endured, Mr. Yang stays true to his heart and knows how to appreciate the small joys of everyday life. A man whose wisdom and maturity I find admirable.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_199")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/3/35/VO_Archive_Argenti_15.ogg/revision/latest?cb=20240114205542
# VO_Archive_Argenti_15.ogg
# Text :  Such a fascinating ball of fluff. I imagine them to be exceptionally fitting perched atop a knight's shoulder, serving as a symbol of honor.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_205")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/3/3b/VO_Archive_Argenti_16.ogg/revision/latest?cb=20240114205543
# VO_Archive_Argenti_16.ogg
# Text :  Haha, such an adorable little creature.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_207")>, <selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_208")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/d/d8/VO_Archive_Argenti_17_M.ogg/revision/latest?cb=20240114205545
# VO_Archive_Argenti_17_M.ogg
# Text :  (Trailblazer)'s inherent qualities, are as beguiling and engaging now as they were on the day we first met.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_210")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/8/80/VO_Archive_Argenti_Eidolon_Activation.ogg/revision/latest?cb=20240124133221
# VO_Archive_Argenti_Eidolon_Activation.ogg
# Text :  The Beauty is universal — they exist within our grasp and beyond the grand expanse of the galaxy.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_212")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/75/VO_Archive_Argenti_Character_Ascension.ogg/revision/latest?cb=20240124133218
# VO_Archive_Argenti_Character_Ascension.ogg
# Text :  One solid stride at a time. Fear not the peril of descent.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_214")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/b/be/VO_Archive_Argenti_Max_Level_Reached.ogg/revision/latest?cb=20240124133222
# VO_Archive_Argenti_Max_Level_Reached.ogg
# Text :  I vow to make the grand name of "the Beauty" echo throughout the universe, till I draw my last breath.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_216")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/9/9c/VO_Archive_Argenti_Trace_Activation.ogg/revision/latest?cb=20240124133223
# VO_Archive_Argenti_Trace_Activation.ogg
# Text :  Though as knights we may tread different paths, destiny will bring us together at journey's end.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_218")>, <selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_219")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/7e/VO_Archive_Argenti_Added_to_Team_With_%28Trailblazer%29_M.ogg/revision/latest?cb=20240124133213
# VO_Archive_Argenti_Added_to_Team_With_%28Trailblazer%29_M.ogg
# Audio : None
# Text :  To stand side by side with a noble soul like you, (Trailblazer), is a great honor.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_221")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/2e/VO_Archive_Argenti_Added_to_Team_With_March_7th.ogg/revision/latest?cb=20240124133217
# VO_Archive_Argenti_Added_to_Team_With_March_7th.ogg
# Text :  If I may, Miss March, allow me to use my modest power to get rid of the gloom!
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_223")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/5/55/VO_Archive_Argenti_Added_to_Team_With_Dan_Heng.ogg/revision/latest?cb=20240124133215
# VO_Archive_Argenti_Added_to_Team_With_Dan_Heng.ogg
# Text :  Combat is a contest of wits. Dan Heng, I am honored to fight by your side.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_225")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/2f/VO_Archive_Argenti_Added_to_Team_With_Himeko.ogg/revision/latest?cb=20240124133216
# VO_Archive_Argenti_Added_to_Team_With_Himeko.ogg
# Text :  Miss Himeko, with your courage ablaze, the stars seem to shine even brighter.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_227")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/8/86/VO_Archive_Argenti_Added_to_Team_With_Welt.ogg/revision/latest?cb=20240124133218
# VO_Archive_Argenti_Added_to_Team_With_Welt.ogg
# Text :  Lend me your aid, Mr. Yang, with your intricate tactics and far-reaching vision.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_257")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/29/VO_Argenti_Battle_Begins_-_Weakness_Break_01.ogg/revision/latest?cb=20240124133225
# VO_Argenti_Battle_Begins_-_Weakness_Break_01.ogg
# Text :  Embrace virtue.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_260")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/4/46/VO_Argenti_Battle_Begins_-_Danger_Alert_01.ogg/revision/latest?cb=20240124133224
# VO_Argenti_Battle_Begins_-_Danger_Alert_01.ogg
# Text :  This storm shall pass.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_281")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/7e/VO_Argenti_Turn_Begins_01.ogg/revision/latest?cb=20240124133328
# VO_Argenti_Turn_Begins_01.ogg
# Text :  My oath is to a solitary rose.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_287")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/8/84/VO_Argenti_Turn_Begins_02.ogg/revision/latest?cb=20240124133329
# VO_Argenti_Turn_Begins_02.ogg
# Text :  The Knights' duty is my guiding light.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_291")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/1/16/VO_Argenti_Turn_Idling_01.ogg/revision/latest?cb=20240124133402
# VO_Argenti_Turn_Idling_01.ogg
# Text :  You who wander, what do your eyes seek?
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_293")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/b/b2/VO_Argenti_Skill_01.ogg/revision/latest?cb=20240124133322
# VO_Argenti_Skill_01.ogg
# Text :  The Beauty... is eternal.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_295")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/d/d3/VO_Argenti_Skill_02.ogg/revision/latest?cb=20240124133323
# VO_Argenti_Skill_02.ogg
# Text :  Wretched... fleeting.
# []
# Audio : None
# Text :  None
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_297")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/9/95/VO_Argenti_Hit_by_Light_Attack_01.ogg/revision/latest?cb=20240124133318
# VO_Argenti_Hit_by_Light_Attack_01.ogg
# Text :  Flesh wound.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_300")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/a/ac/VO_Argenti_Hit_by_Heavy_Attack_01.ogg/revision/latest?cb=20240124133317
# VO_Argenti_Hit_by_Heavy_Attack_01.ogg
# Text :  A test...
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_302")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/d/d9/VO_Argenti_Ultimate_-_Activate_01.ogg/revision/latest?cb=20240124133403
# VO_Argenti_Ultimate_-_Activate_01.ogg
# Text :  Until I see that light once more...
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_304")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/0/0f/VO_Argenti_Ultimate_-_Unleash_01.ogg/revision/latest?cb=20240124133404
# VO_Argenti_Ultimate_-_Unleash_01.ogg
# Text :  ...I will protect all beauty in the universe.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_306")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/20/VO_Argenti_Ultimate_-_Unleash_02.ogg/revision/latest?cb=20240124133405
# VO_Argenti_Ultimate_-_Unleash_02.ogg
# Text :  (Enhanced) ...For Idrila.
# []
# Audio : None
# Text :  None
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_308")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/9/9f/VO_Argenti_Downed_01.ogg/revision/latest?cb=20240124133227
# VO_Argenti_Downed_01.ogg
# Text :  I... couldn't find them...
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_310")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/6/6f/VO_Argenti_Return_to_Battle_01.ogg/revision/latest?cb=20240124133320
# VO_Argenti_Return_to_Battle_01.ogg
# Text :  My faith is unbreakable.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_312")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/74/VO_Argenti_Health_Recovery_01.ogg/revision/latest?cb=20240124133317
# VO_Argenti_Health_Recovery_01.ogg
# Text :  My gratitude is yours.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_314")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/f/fa/VO_Argenti_Technique_01.ogg/revision/latest?cb=20240124133325
# VO_Argenti_Technique_01.ogg
# Text :  Glory above all.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_316")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/72/VO_Argenti_Battle_Won_01.ogg/revision/latest?cb=20240124133226
# VO_Argenti_Battle_Won_01.ogg
# Text :  The darkness ends here.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_318")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/c/cf/VO_Argenti_Treasure_Opening_01.ogg/revision/latest?cb=20240124133326
# VO_Argenti_Treasure_Opening_01.ogg
# Text :  Oh? I do like surprises.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_320")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/7/7b/VO_Argenti_Treasure_Opening_02.ogg/revision/latest?cb=20240124133327
# VO_Argenti_Treasure_Opening_02.ogg
# Text :  I offer you the captivating aroma of a rose.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_322")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/f/f3/VO_Argenti_Precious_Treasure_Opening_01.ogg/revision/latest?cb=20240124133319
# VO_Argenti_Precious_Treasure_Opening_01.ogg
# Text :  A lustrous beauty that sets the heart and soul astir...
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_324")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/8/8d/VO_Argenti_Successful_Puzzle-Solving_01.ogg/revision/latest?cb=20240124133324
# VO_Argenti_Successful_Puzzle-Solving_01.ogg
# Text :  The consequence of wise deliberation.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_326")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/c/cf/VO_Argenti_Successful_Puzzle-Solving_02.ogg/revision/latest?cb=20240124133325
# VO_Argenti_Successful_Puzzle-Solving_02.ogg
# Text :  Worry not, for I shall shoulder this responsibility.
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_328")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/2/22/VO_Argenti_Enemy_Target_Found_01.ogg/revision/latest?cb=20240124133228
# VO_Argenti_Enemy_Target_Found_01.ogg
# Text :  Care to test your skills?
# [<selenium.webdriver.remote.webelement.WebElement (session="9a81f399228d56e6a23f9db7cff13776", element="2B0A2E4FE3C3BD2FCA388783F8EEB377_element_330")>]
# Audio :  https://static.wikia.nocookie.net/houkai-star-rail/images/a/af/VO_Argenti_Returning_to_Town_01.ogg/revision/latest?cb=20240124133321
# VO_Argenti_Returning_to_Town_01.ogg
# Text :  This familiar wind... a call to sweet remembrance.
# []
# Audio : None
# Text :  Characters
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# []
# Audio : None
# Text :  None
# [{'file_name': 'VO_Archive_Argenti_1.ogg', 'text': 'My name is Argenti, I belong to the Knights of Beauty. May this rose convey my heartfelt salutations.'}, {'file_name': 'VO_Archive_Argenti_2.ogg', 'text': 'Should misfortune befall you, do not hesitate to call upon me. I will protect you.'}, {'file_name': 'VO_Archive_Argenti_3.ogg', 'text': "Forgive me, here we must part ways. It is my duty and destiny to traverse the universe alone. I'm sure our paths will converge again, somewhere."}, {'file_name': 'VO_Archive_Argenti_4.ogg', 'text': 'Among the Knights of Beauty, I am one of the Honorclad — we are distinguished by our engraved armor.'}, {'file_name': 'VO_Archive_Argenti_5.ogg', 'text': 'The Knights tend to operate in solitude, spreading the grace of the Goddess far and wide across the universe. Nevertheless, we follow the same code of chivalry.'}, {'file_name': 'VO_Archive_Argenti_6.ogg', 'text': '"One and Only" is the name of my spaceship. I must admit, keeping her in good order can be a chore. Perhaps I shouldn\'t have etched such intricate patterns into the fuselage.'}, {'file_name': 'VO_Archive_Argenti_7.ogg', 'text': "I have a preference for thick, crusty baguettes. Slice them thinly so they're easier to store — a crucial snack for extended voyages."}, {'file_name': 'VO_Archive_Argenti_8.ogg', 'text': 'The dazzling array of entertainment and gourmet delights offered by the IPC is quite staggering, but I regularly struggle with making sense of it all. Perhaps one day someone with experience will show me the ropes.'}, {'file_name': 'VO_Archive_Argenti_9.ogg', 'text': "I've heard tales of warriors on a certain planet passing book pages over artificial limbs in order to infuse knowledge directly into their neural systems. It sounds so outlandish, and yet I find the idea quite inspired."}, {'file_name': 'VO_Archive_Argenti_10.ogg', 'text': 'Did you ever hear tell of a planet where there is no concept of grotesquery? Even more intriguing — the people there have no concept of beauty, either.'}, {'file_name': 'VO_Archive_Argenti_11.ogg', 'text': 'Miss March possesses a pure heart, and such purity is rare and precious — there are far too many people who are inherently vulgar, profit-driven, and adept at flattery. I wish to extend more compassion and esteem towards people like her.'}, {'file_name': 'VO_Archive_Argenti_12.ogg', 'text': "This lady's spirit is admirably noble: Despite the challenges and hardships that Trailblazing entails, she has retained her poise and bravery — qualities that I profoundly admire. It is these qualities that I strive to embody and use against evil."}, {'file_name': 'VO_Archive_Argenti_13.ogg', 'text': 'While Mr. Dan Heng consistently maintains a sense of wariness towards others, his conduct remains unwaveringly honorable, and his expectations of himself are as stringent as the chivalric code. He possesses a unique form of beauty, I must say.'}, {'file_name': 'VO_Archive_Argenti_14.ogg', 'text': 'Despite the things he has endured, Mr. Yang stays true to his heart and knows how to appreciate the small joys of everyday life. A man whose wisdom and maturity I find admirable.'}, {'file_name': 'VO_Archive_Argenti_15.ogg', 'text': "Such a fascinating ball of fluff. I imagine them to be exceptionally fitting perched atop a knight's shoulder, serving as a symbol of honor."}, {'file_name': 'VO_Archive_Argenti_16.ogg', 'text': 'Haha, such an adorable little creature.'}, {'file_name': 'VO_Archive_Argenti_17_M.ogg', 'text': "(Trailblazer)'s inherent qualities, are as beguiling and engaging now as they were on the day we first met."}, {'file_name': 'VO_Archive_Argenti_Eidolon_Activation.ogg', 'text': 'The Beauty is universal — they exist within our grasp and beyond the grand expanse of the galaxy.'}, {'file_name': 'VO_Archive_Argenti_Character_Ascension.ogg', 'text': 'One solid stride at a time. Fear not the peril of descent.'}, {'file_name': 'VO_Archive_Argenti_Max_Level_Reached.ogg', 'text': 'I vow to make the ...
# Complete Downloading!
# now downloading Chractor : Arlan
# Language_ID : Korean
# Downloading With Chrome
